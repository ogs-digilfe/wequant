# %%
from wequant.data_processing import ShikihoOnlinePl

# objects inported in wequant.data_processing
import os, calendar
import polars as pl
import pandas as pd
from typing import Union, Literal
from datetime import date, timedelta
from dateutil.relativedelta import relativedelta
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
from plotly.subplots import make_subplots
from plotly.graph_objects import Figure

# %%
SO = ShikihoOnlinePl()

# %%
from datetime import date
SO.df.filter(pl.col("code")==1301).filter(pl.col("issue")>=date(2024,1,1))
# Out:
# shape: (8, 7)
# ┌──────┬──────┬────────────┬────────────────┬───────────────────┬──────────────┬───────────────────┐
# │ code ┆ name ┆ issue      ┆ title1         ┆ comment1          ┆ title2       ┆ comment2          │
# │ ---  ┆ ---  ┆ ---        ┆ ---            ┆ ---               ┆ ---          ┆ ---               │
# │ i64  ┆ str  ┆ date       ┆ str            ┆ str               ┆ str          ┆ str               │
# ╞══════╪══════╪════════════╪════════════════╪═══════════════════╪══════════════╪═══════════════════╡
# │ 1301 ┆ 極洋 ┆ 2024-03-16 ┆ 【最高益】     ┆ マグロ販売厳しく  ┆ 【増資】     ┆ 公募増資等で最大  │
# │      ┆      ┆            ┆                ┆ 減収ながら、カニ  ┆              ┆ 約43億円調達、全  │
# │      ┆      ┆            ┆                ┆ や魚卵順調で冬場  ┆              ┆ 額借り入れ返済充  │
# │      ┆      ┆            ┆                ┆ の利益大。食…     ┆              ┆ 当。自己資…       │
# │ 1301 ┆ 極洋 ┆ 2024-06-14 ┆ 【連続最高益】 ┆ マグロやサケなど  ┆ 【新中計】   ┆ 26年度売上4000億  │
# │      ┆      ┆            ┆                ┆ 水産市況は堅調。  ┆              ┆ 円、営業益135億円 │
# │      ┆      ┆            ┆                ┆ 水産は取り扱い魚  ┆              ┆ 。海外売上比率15… │
# │      ┆      ┆            ┆                ┆ 種増などで販…     ┆              ┆                   │
# │ 1301 ┆ 極洋 ┆ 2024-09-13 ┆ 【増配】       ┆ 水産は前期苦戦し  ┆ 【業務用】   ┆ 足元で苦戦の業務  │
# │      ┆      ┆            ┆                ┆ たマグロの市況が  ┆              ┆ 用冷凍食品は低価  │
# │      ┆      ┆            ┆                ┆ 上向き。サケ・カ  ┆              ┆ 格帯の商品を拡充  │
# │      ┆      ┆            ┆                ┆ ニも堅調。生…     ┆              ┆ 、下期の売上…     │
# │ 1301 ┆ 極洋 ┆ 2024-12-18 ┆ 【増額】       ┆ 業務用冷凍食品苦  ┆ 【ベトナム】 ┆ 加工食品の新工場  │
# │      ┆      ┆            ┆                ┆ 戦も、市販用伸長  ┆              ┆ が25年2月から本格 │
# │      ┆      ┆            ┆                ┆ 。サケ・エビの販  ┆              ┆ 稼働へ。中国から  │
# │      ┆      ┆            ┆                ┆ 売好調。冷凍…     ┆              ┆ 生産移し…         │
# │ 1301 ┆ 極洋 ┆ 2025-03-19 ┆ 【快走】       ┆ サケやエビ等販売  ┆ 【米国】     ┆ かにかま新工場は1 │
# │      ┆      ┆            ┆                ┆ 増。冷凍マグロな  ┆              ┆ 月に本格稼働。需  │
# │      ┆      ┆            ┆                ┆ どの採算改善が想  ┆              ┆ 要高まる北米での  │
# │      ┆      ┆            ┆                ┆ 定超。増配。…     ┆              ┆ 市場深耕。…       │
# │ 1301 ┆ 極洋 ┆ 2025-06-18 ┆ 【連続増配】   ┆ 水産はマグロの市  ┆ 【だし】     ┆ 業務用だし粉原料  │
# │      ┆      ┆            ┆                ┆ 況悪化も、販売魚  ┆              ┆ の専用工場を4月か │
# │      ┆      ┆            ┆                ┆ 種や販路拡大進む  ┆              ┆ ら稼働。製造を内  │
# │      ┆      ┆            ┆                ┆ 。すしネタは…     ┆              ┆ 製化し効率…       │
# │ 1301 ┆ 極洋 ┆ 2025-09-18 ┆ 【下期回復】   ┆ 上期は国内冷凍食  ┆ 【機構改正】 ┆ 海外で人気高まる  │
# │      ┆      ┆            ┆                ┆ 品など苦戦。が、1 ┆              ┆ 日本産ホタテなど  │
# │      ┆      ┆            ┆                ┆ 0月に加熱用水産加 ┆              ┆ の貝類を専門的に  │
# │      ┆      ┆            ┆                ┆ 工品の買…         ┆              ┆ 扱う課を設置…     │
# │ 1301 ┆ 極洋 ┆ 2025-12-17 ┆ 【連続最高益】 ┆ 市販用食品やカツ  ┆ 【欧州】     ┆ 北欧を拠点とする  │
# │      ┆      ┆            ┆                ┆ オ漁獲が不振で上  ┆              ┆ 水産加工会社を取  │
# │      ┆      ┆            ┆                ┆ 期苦戦も、年末商  ┆              ┆ 得、北欧での販売  │
# │      ┆      ┆            ┆                ┆ 戦でカニなど…     ┆              ┆ 拡大し海外売…     │
# └──────┴──────┴────────────┴────────────────┴───────────────────┴──────────────┴───────────────────┘
