# %%
"""
前年同期の四半期単体決算の比較で、モメンタムデータでフィルタリングし、有効な投資先を探る
"""
# Out:
# '\n前年同期の四半期単体決算の比較で、モメンタムデータでフィルタリングし、有効な投資先を探る\n'

# %%
import os
from wequant.data_processing import read_data
from pathlib import Path

CURRENT_DIR = Path(os.getcwd())
PJ_DIR = CURRENT_DIR.parent
DATA_DIR = PJ_DIR / "data"
FNAME = "kessan.parquet"

# %%
CURRENT_DIR
# Out:
# PosixPath('/home/ogs-digilife/workspace-wequant/wequant/notebooks/screening')

# %%
# 決算parquetを読み込む
df = read_data(DATA_DIR/FNAME)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 決算parquetを読み込む
# ----> 2 df = read_data(DATA_DIR/FNAME)
#
# File ~/workspace-wequant/wequant/lib/lib_dataprocess.py:44, in read_data(fp)
#      41 def read_data(fp: Union[str, Path]) -> pl.DataFrame:
#      42     fp = str(fp)
# ---> 44     return pl.read_parquet(fp)
#
# File ~/workspace-wequant/venv-wequant/lib/python3.12/site-packages/polars/_utils/deprecation.py:92, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      87 @wraps(function)
#      88 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      89     _rename_keyword_argument(
#      90         old_name, new_name, kwargs, function.__qualname__, version
#      91     )
# ---> 92     return function(*args, **kwargs)
#
# ...

# %%
import sys
for p in sys.path:
    print(p)
# Out:
# /home/ogs-digilife/workspace-wequant/wequant
# /home/ogs-digilife/workspace-wequant/wequant/notebooks/screening
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /home/ogs-digilife/workspace-wequant/venv-wequant/lib/python3.12/site-packages
# /home/ogs-digilife/workspace-wequant/wequant
